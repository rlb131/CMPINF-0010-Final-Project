# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# /tmp/ipykernel_15571/2145150660.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
trees = pd.read_csv("trees.csv")
tree_counts = trees["neighborhood"].value_counts().sort_values(ascending=False)

plt.xlabel("Neighborhood")
plt.ylabel("Trees")

tree_counts[:20].plot(kind='bar')
# Out:
# /tmp/ipykernel_15571/3915937178.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   trees = pd.read_csv("trees.csv")
# <Axes: xlabel='neighborhood', ylabel='Trees'>
